# %%
import pydriller

# %%
repo = pydriller.Repository('../mastodon')

# %%
commits = list(repo.traverse_commits())

# %%
commits[0]

# %%
c=commits[0]

# %%
c.hash
# Out:
# '9c4856bdb11fc9311ab30a97224cee3dfaec492f'

# %%
c.author.name
# Out:
# 'Eugen Rochko'

# %%
c.files
# Out:
# 73

# %%
f=c.modified_files

# %%
for each_commit in commits:
    print(each_commit.hash)
# Out:
# 9c4856bdb11fc9311ab30a97224cee3dfaec492f
# 709c6685a90bb819696566cc9e42e587546d72dc
# 1dad72bf13f5e28781a2b2b6654f72624d205576
# 2bc48e9064c56101d1761a10d8c5badba60d2bbe
# 3b0bc18db928c455186273d9b9aa5b96d91e035e
# fa33750105389110a3395ca19167f789d21a149e
# ee73d35eea024894e851d807132c3f21a133152d
# 79baf2fd996c8b69333cf991f4ccf93f0965a744
# 9411e8c35a50b04ac793977a7db44488261daadc
# 784b9cca6ae490216f45e55786b96c5e03257373
# 10eb47a33e2f0c7f0eba5302319c4321db41294c
# fa7868675d0952f8e4e1aa2f6b77586bb56de2c1
# 8da8387afee66e17b3ec864ba84a7a065187818b
# 79609d62705fa7060c1d1ab78234b4aabdbd7e0f
# c967802c4351f34d5c62e52b72c7d5c2d72ffba3
# 42eeecba3f334227c10533a065e238f51f6dee4c
# 71fe24096c612996cb2a827c919a4c88ae1e3495
# 44c5958203dd8d0f96f880a8014a3233719077a6
# f16b31f0773c2fd1122ff0ad98cb392e762f0d0b
# 24646d57690ad36cf4caecab2eec5774bca7f699
# fa29ef3a41816ee915c52707bcd9db6cc9cdf7d6
# 2c70f0ecaa507427d2592434cb4a516bcedd5039
# 5ae54f9e364880e1350ddcc8251a23cf79ae55fc
# ...
